  os.environ["NUM_WORKERS"] = "2"

  os.environ["SEED"] = "42"
  os.environ["SPLIT_SEED"] = "42"
  os.environ["RESUME_MODE"] = "auto"

# %%
# Kaggle IU-Xray controlled dual-GPU runner
# Copy-paste this whole file into one Kaggle Notebook cell.
# Add Kaggle inputs:
#   1) IU-Xray data dataset, e.g. /kaggle/input/iu-xray-384-cleaned
#   2) Code zip dataset containing iu_xray_kaggle_code_controlled.zip
# Optional: add previous output zip/checkpoint dataset and set RESUME_MODE="auto".

import glob
import json
import os
import pathlib
import shutil
import subprocess
import time
import zipfile

os.environ.setdefault("TOKENIZERS_PARALLELISM", "false")
os.environ.setdefault("PYTORCH_CUDA_ALLOC_CONF", "expandable_segments:True")

# =========================
# EDIT THESE SETTINGS ONLY
# =========================
MODE = os.environ.get("MODE", "probe")  # probe or true_run
EMBED_CONFIG = os.environ.get("EMBED_CONFIG", "swin_bioclinicalbert")
BATCH_SIZE = os.environ.get("BATCH_SIZE", "4")
GRAD_ACCUM = os.environ.get("GRAD_ACCUM", "8")
NUM_WORKERS = os.environ.get("NUM_WORKERS", "2")
EPOCHS = os.environ.get("EPOCHS", "3" if MODE == "probe" else "100")
EVAL_EVERY = os.environ.get("EVAL_EVERY", "1" if MODE == "probe" else "5")
FREEZE_EP = os.environ.get("FREEZE_EP", "1" if MODE == "probe" else "5")
CLUSTER_START = os.environ.get("CLUSTER_START", "2" if MODE == "probe" else "12")
CLINICAL_START = os.environ.get("CLINICAL_START", "2" if MODE == "probe" else "15")
SEED = os.environ.get("SEED", "42")
SPLIT_SEED = os.environ.get("SPLIT_SEED", "42")
RESUME_MODE = os.environ.get("RESUME_MODE", "auto")  # auto, off, or explicit checkpoint path
CODE_ZIP_NAME = os.environ.get("CODE_ZIP_NAME", "iu_xray_kaggle_code_controlled.zip")
DATA_ROOT = os.environ.get("DATA_ROOT", "/kaggle/input/iu-xray-384-cleaned")

CONFIGS = {
    "swin_bioclinicalbert": {
        "image_model": "microsoft/swinv2-base-patch4-window12to24-192to384-22kto1k-ft",
        "text_model": "emilyalsentzer/Bio_ClinicalBERT",
    },
    "vit_bioclinicalbert": {
        "image_model": "google/vit-base-patch16-384",
        "text_model": "emilyalsentzer/Bio_ClinicalBERT",
    },
    "convnext_bioclinicalbert": {
        "image_model": "facebook/convnext-base-384-22k-1k",
        "text_model": "emilyalsentzer/Bio_ClinicalBERT",
    },
    "swin_pubmedbert": {
        "image_model": "microsoft/swinv2-base-patch4-window12to24-192to384-22kto1k-ft",
        "text_model": "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext",
    },
}

if EMBED_CONFIG not in CONFIGS:
    raise ValueError(f"Unknown EMBED_CONFIG={EMBED_CONFIG}. Expected one of {sorted(CONFIGS)}")

RUN_ID = f"{EMBED_CONFIG}_{MODE}_seed{SEED}_split{SPLIT_SEED}"
REPO_DIR = pathlib.Path("/kaggle/working/finetune_IU_Xray")
RUN_ROOT = pathlib.Path("/kaggle/working/runs") / RUN_ID
LOG_ROOT = pathlib.Path("/kaggle/working/logs")
OUTPUT_ZIP = pathlib.Path("/kaggle/working") / f"{RUN_ID}_outputs.zip"

print("=== Run config ===")
for key, value in {
    "MODE": MODE,
    "EMBED_CONFIG": EMBED_CONFIG,
    "BATCH_SIZE": BATCH_SIZE,
    "GRAD_ACCUM": GRAD_ACCUM,
    "EPOCHS": EPOCHS,
    "EVAL_EVERY": EVAL_EVERY,
    "FREEZE_EP": FREEZE_EP,
    "CLUSTER_START": CLUSTER_START,
    "CLINICAL_START": CLINICAL_START,
    "SEED": SEED,
    "SPLIT_SEED": SPLIT_SEED,
    "RESUME_MODE": RESUME_MODE,
    "RUN_ID": RUN_ID,
}.items():
    print(f"{key}: {value}")
print("CONFIG:", json.dumps(CONFIGS[EMBED_CONFIG], indent=2))

print("\n=== Kaggle inputs ===")
for p in sorted(glob.glob("/kaggle/input/*")):
    print("\n", p)
    try:
        print(os.listdir(p)[:40])
    except Exception as exc:
        print("  cannot list:", exc)

print("\n=== Setup code ===")
zip_candidates = sorted(glob.glob(f"/kaggle/input/**/{CODE_ZIP_NAME}", recursive=True))
legacy_zip_candidates = sorted(glob.glob("/kaggle/input/**/iu_xray_kaggle_code_smoke_resume.zip", recursive=True))
all_zip_candidates = sorted(glob.glob("/kaggle/input/**/*.zip", recursive=True))
repo_input_candidates = [p for p in sorted(glob.glob("/kaggle/input/**", recursive=True)) if os.path.isdir(p) and os.path.exists(os.path.join(p, "train_ablation.py"))]

print("expected code zip name:", CODE_ZIP_NAME)
print("matching code zips:", zip_candidates)
print("legacy code zips:", legacy_zip_candidates)
print("all input zips:", all_zip_candidates[:50])
print("repo directory candidates:", repo_input_candidates[:20])

shutil.rmtree(REPO_DIR, ignore_errors=True)
REPO_DIR.mkdir(parents=True, exist_ok=True)

def zip_contains_repo(zip_path):
    try:
        with zipfile.ZipFile(zip_path) as zf:
            names = set(zf.namelist())
            return "train_ablation.py" in names or any(name.endswith("/train_ablation.py") for name in names)
    except zipfile.BadZipFile:
        return False

scanned_repo_zips = [p for p in all_zip_candidates if zip_contains_repo(p)]

if zip_candidates:
    code_zip = zip_candidates[0]
    print("CODE_ZIP:", code_zip)
    with zipfile.ZipFile(code_zip) as zf:
        zf.extractall(REPO_DIR)
elif legacy_zip_candidates:
    code_zip = legacy_zip_candidates[0]
    print("LEGACY_CODE_ZIP:", code_zip)
    with zipfile.ZipFile(code_zip) as zf:
        zf.extractall(REPO_DIR)
elif scanned_repo_zips:
    code_zip = scanned_repo_zips[0]
    print("SCANNED_REPO_ZIP:", code_zip)
    with zipfile.ZipFile(code_zip) as zf:
        zf.extractall(REPO_DIR)
elif repo_input_candidates:
    src = repo_input_candidates[0]
    print("CODE_SRC:", src)
    shutil.copytree(src, REPO_DIR, dirs_exist_ok=True)
else:
    raise FileNotFoundError(
        "No repo code input found. Add a Kaggle dataset containing iu_xray_kaggle_code_controlled.zip "
        "or any zip whose root contains train_ablation.py. See printed /kaggle/input list above."
    )

nested_train = list(REPO_DIR.glob("**/train_ablation.py"))
if nested_train and not (REPO_DIR / "train_ablation.py").exists():
    nested_root = nested_train[0].parent
    print("Detected nested repo root:", nested_root)
    for item in nested_root.iterdir():
        target = REPO_DIR / item.name
        if target.exists():
            continue
        shutil.move(str(item), str(target))

os.chdir(REPO_DIR)
for rel in ["train_proposed.py", "train_ablation.py", "train_single_gpu.py", "requirements.txt"]:
    if not os.path.exists(rel):
        raise FileNotFoundError(f"Missing {rel} after code setup in {REPO_DIR}")
print("REPO_DIR:", REPO_DIR)
print("repo files:", os.listdir(".")[:40])

print("\n=== Find IU-Xray data ===")
print("requested DATA_ROOT:", DATA_ROOT)

csv_candidates = []
if os.path.exists(DATA_ROOT + "/data/v8_clean.csv"):
    csv_candidates.append(DATA_ROOT + "/data/v8_clean.csv")
if os.path.exists(DATA_ROOT + "/v8_clean.csv"):
    csv_candidates.append(DATA_ROOT + "/v8_clean.csv")

if not csv_candidates:
    csv_candidates = sorted(glob.glob("/kaggle/input/**/v8_clean.csv", recursive=True))

print("v8_clean.csv candidates:", csv_candidates[:20])
if not csv_candidates:
    raise FileNotFoundError("Cannot find v8_clean.csv under /kaggle/input. Check the IU-Xray dataset input path printed above.")

CSV_PATH = csv_candidates[0]
csv_parent = os.path.dirname(CSV_PATH)
img_candidates = []
for candidate in [
    os.path.join(csv_parent, "images_384"),
    os.path.join(os.path.dirname(csv_parent), "images_384"),
    os.path.join(os.path.dirname(csv_parent), "data", "images_384"),
]:
    if os.path.isdir(candidate):
        img_candidates.append(candidate)
if not img_candidates:
    img_candidates = sorted(glob.glob("/kaggle/input/**/images_384", recursive=True))

print("images_384 candidates:", img_candidates[:20])
if not img_candidates:
    raise FileNotFoundError("Cannot find images_384 under /kaggle/input. Check the IU-Xray dataset input path printed above.")

IMG_DIR = img_candidates[0]
DATA_ROOT = os.path.commonpath([CSV_PATH, IMG_DIR])
print("DATA_ROOT_DETECTED:", DATA_ROOT)
print("CSV_PATH:", CSV_PATH, os.path.exists(CSV_PATH))
print("IMG_DIR:", IMG_DIR, os.path.exists(IMG_DIR))
print("num images:", len(glob.glob(IMG_DIR + "/*")))

print("\n=== Install requirements and check GPUs ===")
subprocess.check_call(["python", "-m", "pip", "install", "-q", "-r", "requirements.txt"])
subprocess.call(["nvidia-smi"])

import torch
print("torch:", torch.__version__)
print("cuda:", torch.cuda.is_available())
print("cuda_device_count:", torch.cuda.device_count())
if not torch.cuda.is_available() or torch.cuda.device_count() < 2:
    raise RuntimeError("Kaggle accelerator must be GPU T4 x2 for this dual-run launcher.")
for idx in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(idx)
    print("gpu", idx, props.name, "vram_gb", round(props.total_memory / 1024**3, 2))

RUN_ROOT.mkdir(parents=True, exist_ok=True)
LOG_ROOT.mkdir(parents=True, exist_ok=True)

run_manifest = {
    "run_id": RUN_ID,
    "mode": MODE,
    "embed_config": EMBED_CONFIG,
    "config": CONFIGS[EMBED_CONFIG],
    "batch_size": BATCH_SIZE,
    "grad_accum": GRAD_ACCUM,
    "epochs": EPOCHS,
    "eval_every": EVAL_EVERY,
    "freeze_ep": FREEZE_EP,
    "cluster_start": CLUSTER_START,
    "clinical_start": CLINICAL_START,
    "seed": SEED,
    "split_seed": SPLIT_SEED,
    "csv_path": CSV_PATH,
    "img_dir": IMG_DIR,
    "resume_mode": RESUME_MODE,
}
(RUN_ROOT / "run_config.json").write_text(json.dumps(run_manifest, indent=2), encoding="utf-8")

def find_resume_checkpoint(method: str) -> str | None:
    if RESUME_MODE.lower() == "off":
        return None
    if RESUME_MODE.lower() != "auto":
        return RESUME_MODE

    candidates = []
    for root in sorted(glob.glob("/kaggle/input/*")):
        patterns = [
            f"{root}/**/{RUN_ID}/{method}/last.pt",
            f"{root}/**/{RUN_ID}/{method}/best.pt",
            f"{root}/**/{EMBED_CONFIG}_{MODE}/{method}/last.pt",
            f"{root}/**/{method}/last.pt",
        ]
        for pattern in patterns:
            candidates.extend(glob.glob(pattern, recursive=True))
    candidates = sorted(set(candidates), key=lambda x: ("last.pt" not in x, x))
    return candidates[0] if candidates else None

common_args = [
    "--csv_path", CSV_PATH,
    "--img_dir", IMG_DIR,
    "--epochs", EPOCHS,
    "--batch_size", BATCH_SIZE,
    "--grad_accum", GRAD_ACCUM,
    "--eval_every", EVAL_EVERY,
    "--freeze_ep", FREEZE_EP,
    "--num_workers", NUM_WORKERS,
    "--seed", SEED,
    "--split_seed", SPLIT_SEED,
    "--image_model", CONFIGS[EMBED_CONFIG]["image_model"],
    "--text_model", CONFIGS[EMBED_CONFIG]["text_model"],
]

strict_cmd = [
    "python", "-u", "train_ablation.py", "study_multiview_strict",
    "--out_dir", str(RUN_ROOT / "strict"),
    *common_args,
]
proposed_cmd = [
    "python", "-u", "train_ablation.py", "proposed",
    "--out_dir", str(RUN_ROOT / "proposed"),
    *common_args,
    "--cluster_start", CLUSTER_START,
    "--clinical_start", CLINICAL_START,
]

commands = [
    ("strict", "0", strict_cmd),
    ("proposed", "1", proposed_cmd),
]

processes = []
start_time = time.time()
for name, gpu, cmd in commands:
    resume = find_resume_checkpoint(name)
    if resume:
        cmd = [*cmd, "--resume", resume]
    out_dir = RUN_ROOT / name
    out_dir.mkdir(parents=True, exist_ok=True)
    env = os.environ.copy()
    env["CUDA_VISIBLE_DEVICES"] = gpu
    log_path = LOG_ROOT / f"{RUN_ID}_{name}.log"
    launcher_info = {
        "name": name,
        "gpu": gpu,
        "cmd": cmd,
        "log_path": str(log_path),
        "out_dir": str(out_dir),
        "resume": resume or "",
    }
    (out_dir / "launcher_config.json").write_text(json.dumps(launcher_info, indent=2), encoding="utf-8")
    print("\n=== Launch", name, "on GPU", gpu, "===")
    print("OUT_DIR:", out_dir)
    print("LOG:", log_path)
    print("RESUME:", resume or "none")
    print("CMD:", " ".join(cmd))
    log_f = open(log_path, "w", encoding="utf-8")
    log_f.write(json.dumps(launcher_info, indent=2) + "\n\n")
    log_f.flush()
    proc = subprocess.Popen(cmd, stdout=log_f, stderr=subprocess.STDOUT, env=env, text=True)
    processes.append((name, proc, log_f, log_path))

failed = []
log_positions = {name: 0 for name, _, _, _ in processes}
print("\n=== Streaming training logs every 10 seconds ===", flush=True)
while True:
    all_done = True
    for name, proc, log_f, log_path in processes:
        if proc.poll() is None:
            all_done = False
        log_f.flush()
        try:
            with open(log_path, "r", encoding="utf-8", errors="replace") as reader:
                reader.seek(log_positions[name])
                new_text = reader.read()
                log_positions[name] = reader.tell()
        except FileNotFoundError:
            new_text = ""
        if new_text:
            for line in new_text.rstrip().splitlines():
                print(f"[{name}] {line}", flush=True)
    if all_done:
        break
    time.sleep(10)

for name, proc, log_f, log_path in processes:
    ret = proc.wait()
    log_f.close()
    print("FINISHED:", name, "returncode", ret, "log", log_path)
    if ret != 0:
        failed.append((name, ret, str(log_path)))

elapsed = round(time.time() - start_time, 1)
print("elapsed_seconds:", elapsed)

print("\n=== Output check ===")
for method in ["strict", "proposed"]:
    out_dir = RUN_ROOT / method
    print("\n", method, out_dir)
    if out_dir.exists():
        print(os.listdir(out_dir))
    for filename in ["train.log", "progress.log", "history.csv", "latest_metrics.json", "test_results.json", "last.pt", "best.pt", "launcher_config.json"]:
        path = out_dir / filename
        print(filename, path.exists(), round(path.stat().st_size / 1024**2, 3) if path.exists() else None)
    log_path = LOG_ROOT / f"{RUN_ID}_{method}.log"
    print("launcher_log", log_path.exists(), round(log_path.stat().st_size / 1024**2, 3) if log_path.exists() else None)

print("\n=== Zip outputs ===")
if OUTPUT_ZIP.exists():
    OUTPUT_ZIP.unlink()
zip_base = str(OUTPUT_ZIP).replace(".zip", "")
shutil.make_archive(zip_base, "zip", "/kaggle/working", "runs")
with zipfile.ZipFile(OUTPUT_ZIP, "a", compression=zipfile.ZIP_DEFLATED) as zf:
    for log_file in LOG_ROOT.glob(f"{RUN_ID}_*.log"):
        zf.write(log_file, arcname=f"logs/{log_file.name}")
print("Created:", OUTPUT_ZIP)
print("size_mb:", round(OUTPUT_ZIP.stat().st_size / 1024**2, 2))

if failed:
    raise RuntimeError(f"Some runs failed: {failed}")
print("DONE")
# Out:
# === Run config ===
# MODE: true_run
# EMBED_CONFIG: convnext_bioclinicalbert
# BATCH_SIZE: 6
# GRAD_ACCUM: 5
# EPOCHS: 150
# EVAL_EVERY: 5
# FREEZE_EP: 5
# CLUSTER_START: 12
# CLINICAL_START: 15
# SEED: 42
# SPLIT_SEED: 42
# RESUME_MODE: auto
# RUN_ID: convnext_bioclinicalbert_true_run_seed42_split42
# CONFIG: {
#   "image_model": "facebook/convnext-base-384-22k-1k",
#   "text_model": "emilyalsentzer/Bio_ClinicalBERT"
# }
#
# === Kaggle inputs ===
#
#  /kaggle/input/datasets
# ['diplailai']
#
# === Setup code ===
# expected code zip name: iu_xray_kaggle_code_controlled.zip
# matching code zips: []
# legacy code zips: []
# all input zips: []
# repo directory candidates: ['/kaggle/input/datasets/diplailai/iu-xray-kaggle-code-controlled']
# CODE_SRC: /kaggle/input/datasets/diplailai/iu-xray-kaggle-code-controlled
# REPO_DIR: /kaggle/working/finetune_IU_Xray
# repo files: ['benchmark_suite', 'train.py', 'src', 'README.md', 'train_ablation.py', 'train_single_gpu.py', 'requirements.txt', 'data_processing', 'train_proposed.py']
#
# === Find IU-Xray data ===
# requested DATA_ROOT: /kaggle/input/iu-xray-384-cleaned
# v8_clean.csv candidates: ['/kaggle/input/datasets/diplailai/iu-xray-384-cleaned/v8_clean.csv']
# images_384 candidates: ['/kaggle/input/datasets/diplailai/iu-xray-384-cleaned/images_384']
# DATA_ROOT_DETECTED: /kaggle/input/datasets/diplailai/iu-xray-384-cleaned
# CSV_PATH: /kaggle/input/datasets/diplailai/iu-xray-384-cleaned/v8_clean.csv True
# IMG_DIR: /kaggle/input/datasets/diplailai/iu-xray-384-cleaned/images_384 True
# num images: 7322
#
# === Install requirements and check GPUs ===
# Sun May 17 07:03:10 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   43C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# torch: 2.10.0+cu128
# cuda: True
# cuda_device_count: 2
# gpu 0 Tesla T4 vram_gb 14.56
# gpu 1 Tesla T4 vram_gb 14.56
#
# === Launch strict on GPU 0 ===
# OUT_DIR: /kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/strict
# LOG: /kaggle/working/logs/convnext_bioclinicalbert_true_run_seed42_split42_strict.log
# RESUME: none
# CMD: python -u train_ablation.py study_multiview_strict --out_dir /kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/strict --csv_path /kaggle/input/datasets/diplailai/iu-xray-384-cleaned/v8_clean.csv --img_dir /kaggle/input/datasets/diplailai/iu-xray-384-cleaned/images_384 --epochs 150 --batch_size 6 --grad_accum 5 --eval_every 5 --freeze_ep 5 --num_workers 2 --seed 42 --split_seed 42 --image_model facebook/convnext-base-384-22k-1k --text_model emilyalsentzer/Bio_ClinicalBERT
#
# === Launch proposed on GPU 1 ===
# OUT_DIR: /kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/proposed
# LOG: /kaggle/working/logs/convnext_bioclinicalbert_true_run_seed42_split42_proposed.log
# RESUME: none
# CMD: python -u train_ablation.py proposed --out_dir /kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/proposed --csv_path /kaggle/input/datasets/diplailai/iu-xray-384-cleaned/v8_clean.csv --img_dir /kaggle/input/datasets/diplailai/iu-xray-384-cleaned/images_384 --epochs 150 --batch_size 6 --grad_accum 5 --eval_every 5 --freeze_ep 5 --num_workers 2 --seed 42 --split_seed 42 --image_model facebook/convnext-base-384-22k-1k --text_model emilyalsentzer/Bio_ClinicalBERT --cluster_start 12 --clinical_start 15
#
# === Streaming training logs every 10 seconds ===
# [strict] {
# [strict]   "name": "strict",
# [strict]   "gpu": "0",
# [strict]   "cmd": [
# [strict]     "python",
# [strict]     "-u",
# [strict]     "train_ablation.py",
# [strict]     "study_multiview_strict",
# [strict]     "--out_dir",
# [strict]     "/kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/strict",
# [strict]     "--csv_path",
# [strict]     "/kaggle/input/datasets/diplailai/iu-xray-384-cleaned/v8_clean.csv",
# [strict]     "--img_dir",
# [strict]     "/kaggle/input/datasets/diplailai/iu-xray-384-cleaned/images_384",
# [strict]     "--epochs",
# [strict]     "150",
# [strict]     "--batch_size",
# [strict]     "6",
# [strict]     "--grad_accum",
# [strict]     "5",
# [strict]     "--eval_every",
# [strict]     "5",
# [strict]     "--freeze_ep",
# [strict]     "5",
# [strict]     "--num_workers",
# [strict]     "2",
# [strict]     "--seed",
# [strict]     "42",
# [strict]     "--split_seed",
# [strict]     "42",
# [strict]     "--image_model",
# [strict]     "facebook/convnext-base-384-22k-1k",
# [strict]     "--text_model",
# [strict]     "emilyalsentzer/Bio_ClinicalBERT"
# [strict]   ],
# [strict]   "log_path": "/kaggle/working/logs/convnext_bioclinicalbert_true_run_seed42_split42_strict.log",
# [strict]   "out_dir": "/kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/strict",
# [strict]   "resume": ""
# [strict] }
# [proposed] {
# [proposed]   "name": "proposed",
# [proposed]   "gpu": "1",
# [proposed]   "cmd": [
# [proposed]     "python",
# [proposed]     "-u",
# [proposed]     "train_ablation.py",
# [proposed]     "proposed",
# [proposed]     "--out_dir",
# [proposed]     "/kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/proposed",
# [proposed]     "--csv_path",
# [proposed]     "/kaggle/input/datasets/diplailai/iu-xray-384-cleaned/v8_clean.csv",
# [proposed]     "--img_dir",
# [proposed]     "/kaggle/input/datasets/diplailai/iu-xray-384-cleaned/images_384",
# [proposed]     "--epochs",
# [proposed]     "150",
# [proposed]     "--batch_size",
# [proposed]     "6",
# [proposed]     "--grad_accum",
# [proposed]     "5",
# [proposed]     "--eval_every",
# [proposed]     "5",
# [proposed]     "--freeze_ep",
# [proposed]     "5",
# [proposed]     "--num_workers",
# [proposed]     "2",
# [proposed]     "--seed",
# [proposed]     "42",
# [proposed]     "--split_seed",
# [proposed]     "42",
# [proposed]     "--image_model",
# [proposed]     "facebook/convnext-base-384-22k-1k",
# [proposed]     "--text_model",
# [proposed]     "emilyalsentzer/Bio_ClinicalBERT",
# [proposed]     "--cluster_start",
# [proposed]     "12",
# [proposed]     "--clinical_start",
# [proposed]     "15"
# [proposed]   ],
# [proposed]   "log_path": "/kaggle/working/logs/convnext_bioclinicalbert_true_run_seed42_split42_proposed.log",
# [proposed]   "out_dir": "/kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/proposed",
# [proposed]   "resume": ""
# [proposed] }
# [strict] [07:03:38] ========================================================================
# [strict] [07:03:38] Study-level IU-Xray retrieval training
# [strict] [07:03:38] Goal: strict patient retrieval + cluster-aware false-negative mitigation
# [strict] [07:03:38] ========================================================================
# [strict] [07:03:38] Device       : cuda
# [strict] [07:03:38] GPU          : Tesla T4
# [strict] [07:03:38] VRAM         : 14912 MB
# [strict] [07:03:38] Batch size   : 6
# [strict] [07:03:38] Grad accum   : 5
# [strict] [07:03:38] Eff batch    : 30
# [strict] [07:03:38] Epochs       : 150
# [strict] [07:03:38] Seed         : 42
# [strict] [07:03:38] Split seed   : 42
# [strict] [07:03:38] Freeze ep    : 5
# [strict] [07:03:38] Max views    : 2
# [strict] [07:03:38] Image model  : facebook/convnext-base-384-22k-1k
# [strict] [07:03:38] Text model   : emilyalsentzer/Bio_ClinicalBERT
# [strict] [07:03:38] Cluster start: 999
# [strict] [07:03:38] IDF-Jaccard  : True
# [strict] [07:03:38] Healthy clus.: True
# [strict] [07:03:38] Clinical start: 999
# [strict] [07:03:38] Clinical w   : 0.0
# [strict] [07:03:38] Clinical schedule: False
# [strict] [07:03:38] Out dir      : /kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/strict
# [strict] [07:03:38] Train rows/studies: 5865 / 3018
# [strict] [07:03:38] Val rows/studies  : 733 / 377
# [strict] [07:03:38] Test rows/studies : 724 / 377
# [strict] [07:03:41] Train/val/test studies: 3018 / 377 / 377
# [strict] [07:03:41] Study batches: 503
# [strict] Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [strict]
# [strict] Loading weights:   0%|          | 0/342 [00:00<?, ?it/s]
# [strict] Loading weights:   0%|          | 1/342 [00:00<00:00, 11983.73it/s, Materializing param=embeddings.layernorm.bias]
# [strict] Loading weights:   0%|          | 1/342 [00:00<00:00, 4332.96it/s, Materializing param=embeddings.layernorm.bias]
# [strict] Loading weights:   1%|          | 2/342 [00:00<00:00, 1086.04it/s, Materializing param=embeddings.layernorm.weight]
# [strict] Loading weights:   1%|          | 2/342 [00:00<00:00, 963.43it/s, Materializing param=embeddings.layernorm.weight]
# [strict] Loading weights:   1%|          | 3/342 [00:00<00:00, 857.73it/s, Materializing param=embeddings.patch_embeddings.bias]
# [strict] Loading weights:   1%|          | 3/342 [00:00<00:00, 635.69it/s, Materializing param=embeddings.patch_embeddings.bias]
# [strict] Loading weights:   1%|          | 4/342 [00:00<00:00, 530.94it/s, Materializing param=embeddings.patch_embeddings.weight]
# [strict] Loading weights:   1%|          | 4/342 [00:00<00:00, 445.00it/s, Materializing param=embeddings.patch_embeddings.weight]
# [strict] Loading weights:   1%|▏         | 5/342 [00:00<00:00, 526.00it/s, Materializing param=encoder.stages.0.layers.0.dwconv.bias]
# [strict] Loading weights:   1%|▏         | 5/342 [00:00<00:00, 490.48it/s, Materializing param=encoder.stages.0.layers.0.dwconv.bias]
# [strict] Loading weights:   2%|▏         | 6/342 [00:00<00:00, 551.14it/s, Materializing param=encoder.stages.0.layers.0.dwconv.weight]
# [strict] Loading weights:   2%|▏         | 6/342 [00:00<00:00, 511.68it/s, Materializing param=encoder.stages.0.layers.0.dwconv.weight]
# [strict] Loading weights:   2%|▏         | 7/342 [00:00<00:00, 516.24it/s, Materializing param=encoder.stages.0.layers.0.layer_scale_parameter]
# [strict] Loading weights:   2%|▏         | 7/342 [00:00<00:00, 487.01it/s, Materializing param=encoder.stages.0.layers.0.layer_scale_parameter]
# [strict] Loading weights:   2%|▏         | 8/342 [00:00<00:00, 518.22it/s, Materializing param=encoder.stages.0.layers.0.layernorm.bias]
# [strict] Loading weights:   2%|▏         | 8/342 [00:00<00:00, 511.81it/s, Materializing param=encoder.stages.0.layers.0.layernorm.bias]
# [strict] Loading weights:   3%|▎         | 9/342 [00:00<00:00, 560.96it/s, Materializing param=encoder.stages.0.layers.0.layernorm.weight]
# [strict] Loading weights:   3%|▎         | 9/342 [00:00<00:00, 557.08it/s, Materializing param=encoder.stages.0.layers.0.layernorm.weight]
# [strict] Loading weights:   3%|▎         | 10/342 [00:00<00:00, 610.05it/s, Materializing param=encoder.stages.0.layers.0.pwconv1.bias]
# [strict] Loading weights:   3%|▎         | 10/342 [00:00<00:00, 603.84it/s, Materializing param=encoder.stages.0.layers.0.pwconv1.bias]
# [strict] Loading weights:   3%|▎         | 11/342 [00:00<00:00, 657.13it/s, Materializing param=encoder.stages.0.layers.0.pwconv1.weight]
# [strict] Loading weights:   3%|▎         | 11/342 [00:00<00:00, 652.63it/s, Materializing param=encoder.stages.0.layers.0.pwconv1.weight]
# [strict] Loading weights:   4%|▎         | 12/342 [00:00<00:00, 704.21it/s, Materializing param=encoder.stages.0.layers.0.pwconv2.bias]
# [strict] Loading weights:   4%|▎         | 12/342 [00:00<00:00, 699.83it/s, Materializing param=encoder.stages.0.layers.0.pwconv2.bias]
# [strict] Loading weights:   4%|▍         | 13/342 [00:00<00:00, 749.81it/s, Materializing param=encoder.stages.0.layers.0.pwconv2.weight]
# [strict] Loading weights:   4%|▍         | 13/342 [00:00<00:00, 746.35it/s, Materializing param=encoder.stages.0.layers.0.pwconv2.weight]
# [strict] Loading weights:   4%|▍         | 14/342 [00:00<00:00, 798.21it/s, Materializing param=encoder.stages.0.layers.1.dwconv.bias]
# [strict] Loading weights:   4%|▍         | 14/342 [00:00<00:00, 795.84it/s, Materializing param=encoder.stages.0.layers.1.dwconv.bias]
# [strict] Loading weights:   4%|▍         | 15/342 [00:00<00:00, 848.28it/s, Materializing param=encoder.stages.0.layers.1.dwconv.weight]
# [strict] Loading weights:   4%|▍         | 15/342 [00:00<00:00, 845.91it/s, Materializing param=encoder.stages.0.layers.1.dwconv.weight]
# [strict] Loading weights:   5%|▍         | 16/342 [00:00<00:00, 897.89it/s, Materializing param=encoder.stages.0.layers.1.layer_scale_parameter]
# [strict] Loading weights:   5%|▍         | 16/342 [00:00<00:00, 895.49it/s, Materializing param=encoder.stages.0.layers.1.layer_scale_parameter]
# [strict] Loading weights:   5%|▍         | 17/342 [00:00<00:00, 946.93it/s, Materializing param=encoder.stages.0.layers.1.layernorm.bias]
# [strict] Loading weights:   5%|▍         | 17/342 [00:00<00:00, 944.49it/s, Materializing param=encoder.stages.0.layers.1.layernorm.bias]
# [strict] Loading weights:   5%|▌         | 18/342 [00:00<00:00, 995.34it/s, Materializing param=encoder.stages.0.layers.1.layernorm.weight]
# [strict] Loading weights:   5%|▌         | 18/342 [00:00<00:00, 992.80it/s, Materializing param=encoder.stages.0.layers.1.layernorm.weight]
# [strict] Loading weights:   6%|▌         | 19/342 [00:00<00:00, 1043.09it/s, Materializing param=encoder.stages.0.layers.1.pwconv1.bias]
# [strict] Loading weights:   6%|▌         | 19/342 [00:00<00:00, 1040.47it/s, Materializing param=encoder.stages.0.layers.1.pwconv1.bias]
# [strict] Loading weights:   6%|▌         | 20/342 [00:00<00:00, 1086.90it/s, Materializing param=encoder.stages.0.layers.1.pwconv1.weight]
# [strict] Loading weights:   6%|▌         | 20/342 [00:00<00:00, 1082.99it/s, Materializing param=encoder.stages.0.layers.1.pwconv1.weight]
# [strict] Loading weights:   6%|▌         | 21/342 [00:00<00:00, 1131.41it/s, Materializing param=encoder.stages.0.layers.1.pwconv2.bias]
# [strict] Loading weights:   6%|▌         | 21/342 [00:00<00:00, 1128.48it/s, Materializing param=encoder.stages.0.layers.1.pwconv2.bias]
# [strict] Loading weights:   6%|▋         | 22/342 [00:00<00:00, 1176.69it/s, Materializing param=encoder.stages.0.layers.1.pwconv2.weight]
# [strict] Loading weights:   6%|▋         | 22/342 [00:00<00:00, 1173.46it/s, Materializing param=encoder.stages.0.layers.1.pwconv2.weight]
# [strict] Loading weights:   7%|▋         | 23/342 [00:00<00:00, 1221.08it/s, Materializing param=encoder.stages.0.layers.2.dwconv.bias]
# [strict] Loading weights:   7%|▋         | 23/342 [00:00<00:00, 1217.46it/s, Materializing param=encoder.stages.0.layers.2.dwconv.bias]
# [strict] Loading weights:   7%|▋         | 24/342 [00:00<00:00, 1264.26it/s, Materializing param=encoder.stages.0.layers.2.dwconv.weight]
# [strict] Loading weights:   7%|▋         | 24/342 [00:00<00:00, 1261.07it/s, Materializing param=encoder.stages.0.layers.2.dwconv.weight]
# [strict] Loading weights:   7%|▋         | 25/342 [00:00<00:00, 1307.57it/s, Materializing param=encoder.stages.0.layers.2.layer_scale_parameter]
# [strict] Loading weights:   7%|▋         | 25/342 [00:00<00:00, 1304.28it/s, Materializing param=encoder.stages.0.layers.2.layer_scale_parameter]
# [strict] Loading weights:   8%|▊         | 26/342 [00:00<00:00, 1350.39it/s, Materializing param=encoder.stages.0.layers.2.layernorm.bias]
# [strict] Loading weights:   8%|▊         | 26/342 [00:00<00:00, 1344.73it/s, Materializing param=encoder.stages.0.layers.2.layernorm.bias]
# [strict] Loading weights:   8%|▊         | 27/342 [00:00<00:00, 1387.09it/s, Materializing param=encoder.stages.0.layers.2.layernorm.weight]
# [strict] Loading weights:   8%|▊         | 27/342 [00:00<00:00, 1383.40it/s, Materializing param=encoder.stages.0.layers.2.layernorm.weight]
# [strict] Loading weights:   8%|▊         | 28/342 [00:00<00:00, 1427.78it/s, Materializing param=encoder.stages.0.layers.2.pwconv1.bias]
# [strict] Loading weights:   8%|▊         | 28/342 [00:00<00:00, 1424.35it/s, Materializing param=encoder.stages.0.layers.2.pwconv1.bias]
# [strict] Loading weights:   8%|▊         | 29/342 [00:00<00:00, 1468.58it/s, Materializing param=encoder.stages.0.layers.2.pwconv1.weight]
# [strict] Loading weights:   8%|▊         | 29/342 [00:00<00:00, 1464.99it/s, Materializing param=encoder.stages.0.layers.2.pwconv1.weight]
# [strict] Loading weights:   9%|▉         | 30/342 [00:00<00:00, 1509.03it/s, Materializing param=encoder.stages.0.layers.2.pwconv2.bias]
# [strict] Loading weights:   9%|▉         | 30/342 [00:00<00:00, 1505.53it/s, Materializing param=encoder.stages.0.layers.2.pwconv2.bias]
# [strict] Loading weights:   9%|▉         | 31/342 [00:00<00:00, 1549.17it/s, Materializing param=encoder.stages.0.layers.2.pwconv2.weight]
# [strict] Loading weights:   9%|▉         | 31/342 [00:00<00:00, 1545.63it/s, Materializing param=encoder.stages.0.layers.2.pwconv2.weight]
# [strict] Loading weights:   9%|▉         | 32/342 [00:00<00:00, 1588.90it/s, Materializing param=encoder.stages.1.downsampling_layer.0.bias]
# [strict] Loading weights:   9%|▉         | 32/342 [00:00<00:00, 1585.32it/s, Materializing param=encoder.stages.1.downsampling_layer.0.bias]
# [strict] Loading weights:  10%|▉         | 33/342 [00:00<00:00, 1628.09it/s, Materializing param=encoder.stages.1.downsampling_layer.0.weight]
# [strict] Loading weights:  10%|▉         | 33/342 [00:00<00:00, 1622.61it/s, Materializing param=encoder.stages.1.downsampling_layer.0.weight]
# [strict] Loading weights:  10%|▉         | 34/342 [00:00<00:00, 1664.08it/s, Materializing param=encoder.stages.1.downsampling_layer.1.bias]
# [strict] Loading weights:  10%|▉         | 34/342 [00:00<00:00, 1659.56it/s, Materializing param=encoder.stages.1.downsampling_layer.1.bias]
# [strict] Loading weights:  10%|█         | 35/342 [00:00<00:00, 1700.91it/s, Materializing param=encoder.stages.1.downsampling_layer.1.weight]
# [strict] Loading weights:  10%|█         | 35/342 [00:00<00:00, 1697.00it/s, Materializing param=encoder.stages.1.downsampling_layer.1.weight]
# [strict] Loading weights:  11%|█         | 36/342 [00:00<00:00, 1738.39it/s, Materializing param=encoder.stages.1.layers.0.dwconv.bias]
# [strict] Loading weights:  11%|█         | 36/342 [00:00<00:00, 1734.56it/s, Materializing param=encoder.stages.1.layers.0.dwconv.bias]
# [strict] Loading weights:  11%|█         | 37/342 [00:00<00:00, 1775.36it/s, Materializing param=encoder.stages.1.layers.0.dwconv.weight]
# [strict] Loading weights:  11%|█         | 37/342 [00:00<00:00, 1771.53it/s, Materializing param=encoder.stages.1.layers.0.dwconv.weight]
# [strict] Loading weights:  11%|█         | 38/342 [00:00<00:00, 1812.14it/s, Materializing param=encoder.stages.1.layers.0.layer_scale_parameter]
# [strict] Loading weights:  11%|█         | 38/342 [00:00<00:00, 1808.07it/s, Materializing param=encoder.stages.1.layers.0.layer_scale_parameter]
# [strict] Loading weights:  11%|█▏        | 39/342 [00:00<00:00, 1847.56it/s, Materializing param=encoder.stages.1.layers.0.layernorm.bias]
# [strict] Loading weights:  11%|█▏        | 39/342 [00:00<00:00, 1843.44it/s, Materializing param=encoder.stages.1.layers.0.layernorm.bias]
# [strict] Loading weights:  12%|█▏        | 40/342 [00:00<00:00, 1883.15it/s, Materializing param=encoder.stages.1.layers.0.layernorm.weight]
# [strict] Loading weights:  12%|█▏        | 40/342 [00:00<00:00, 1879.04it/s, Materializing param=encoder.stages.1.layers.0.layernorm.weight]
# [strict] Loading weights:  12%|█▏        | 41/342 [00:00<00:00, 1916.21it/s, Materializing param=encoder.stages.1.layers.0.pwconv1.bias]
# [strict] Loading weights:  12%|█▏        | 41/342 [00:00<00:00, 1911.97it/s, Materializing param=encoder.stages.1.layers.0.pwconv1.bias]
# [strict] Loading weights:  12%|█▏        | 42/342 [00:00<00:00, 1950.06it/s, Materializing param=encoder.stages.1.layers.0.pwconv1.weight]
# [strict] Loading weights:  12%|█▏        | 42/342 [00:00<00:00, 1945.88it/s, Materializing param=encoder.stages.1.layers.0.pwconv1.weight]
# [strict] Loading weights:  13%|█▎        | 43/342 [00:00<00:00, 1984.41it/s, Materializing param=encoder.stages.1.layers.0.pwconv2.bias]
# [strict] Loading weights:  13%|█▎        | 43/342 [00:00<00:00, 1980.25it/s, Materializing param=encoder.stages.1.layers.0.pwconv2.bias]
# [strict] Loading weights:  13%|█▎        | 44/342 [00:00<00:00, 2018.57it/s, Materializing param=encoder.stages.1.layers.0.pwconv2.weight]
# [strict] Loading weights:  13%|█▎        | 44/342 [00:00<00:00, 2014.38it/s, Materializing param=encoder.stages.1.layers.0.pwconv2.weight]
# [strict] Loading weights:  13%|█▎        | 45/342 [00:00<00:00, 2052.41it/s, Materializing param=encoder.stages.1.layers.1.dwconv.bias]
# [strict] Loading weights:  13%|█▎        | 45/342 [00:00<00:00, 2048.22it/s, Materializing param=encoder.stages.1.layers.1.dwconv.bias]
# [strict] Loading weights:  13%|█▎        | 46/342 [00:00<00:00, 2085.75it/s, Materializing param=encoder.stages.1.layers.1.dwconv.weight]
# [strict] Loading weights:  13%|█▎        | 46/342 [00:00<00:00, 2081.50it/s, Materializing param=encoder.stages.1.layers.1.dwconv.weight]
# [strict] Loading weights:  14%|█▎        | 47/342 [00:00<00:00, 2118.84it/s, Materializing param=encoder.stages.1.layers.1.layer_scale_parameter]
# [strict] Loading weights:  14%|█▎        | 47/342 [00:00<00:00, 2114.40it/s, Materializing param=encoder.stages.1.layers.1.layer_scale_parameter]
# [strict] Loading weights:  14%|█▍        | 48/342 [00:00<00:00, 2149.96it/s, Materializing param=encoder.stages.1.layers.1.layernorm.bias]
# [strict] Loading weights:  14%|█▍        | 48/342 [00:00<00:00, 2144.97it/s, Materializing param=encoder.stages.1.layers.1.layernorm.bias]
# [strict] Loading weights:  14%|█▍        | 49/342 [00:00<00:00, 2180.43it/s, Materializing param=encoder.stages.1.layers.1.layernorm.weight]
# [strict] Loading weights:  14%|█▍        | 49/342 [00:00<00:00, 2175.86it/s, Materializing param=encoder.stages.1.layers.1.layernorm.weight]
# [strict] Loading weights:  15%|█▍        | 50/342 [00:00<00:00, 2212.00it/s, Materializing param=encoder.stages.1.layers.1.pwconv1.bias]
# [strict] Loading weights:  15%|█▍        | 50/342 [00:00<00:00, 2207.53it/s, Materializing param=encoder.stages.1.layers.1.pwconv1.bias]
# [strict] Loading weights:  15%|█▍        | 51/342 [00:00<00:00, 2243.53it/s, Materializing param=encoder.stages.1.layers.1.pwconv1.weight]
# [strict] Loading weights:  15%|█▍        | 51/342 [00:00<00:00, 2239.07it/s, Materializing param=encoder.stages.1.layers.1.pwconv1.weight]
# [strict] Loading weights:  15%|█▌        | 52/342 [00:00<00:00, 2274.90it/s, Materializing param=encoder.stages.1.layers.1.pwconv2.bias]
# [strict] Loading weights:  15%|█▌        | 52/342 [00:00<00:00, 2270.47it/s, Materializing param=encoder.stages.1.layers.1.pwconv2.bias]
# [strict] Loading weights:  15%|█▌        | 53/342 [00:00<00:00, 2306.02it/s, Materializing param=encoder.stages.1.layers.1.pwconv2.weight]
# [strict] Loading weights:  15%|█▌        | 53/342 [00:00<00:00, 2301.56it/s, Materializing param=encoder.stages.1.layers.1.pwconv2.weight]
# [strict] Loading weights:  16%|█▌        | 54/342 [00:00<00:00, 2335.24it/s, Materializing param=encoder.stages.1.layers.2.dwconv.bias]
# [strict] Loading weights:  16%|█▌        | 54/342 [00:00<00:00, 2330.62it/s, Materializing param=encoder.stages.1.layers.2.dwconv.bias]
# [strict] Loading weights:  16%|█▌        | 55/342 [00:00<00:00, 2365.29it/s, Materializing param=encoder.stages.1.layers.2.dwconv.weight]
# [strict] Loading weights:  16%|█▌        | 55/342 [00:00<00:00, 2359.36it/s, Materializing param=encoder.stages.1.layers.2.dwconv.weight]
# [strict] Loading weights:  16%|█▋        | 56/342 [00:00<00:00, 2392.64it/s, Materializing param=encoder.stages.1.layers.2.layer_scale_parameter]
# [strict] Loading weights:  16%|█▋        | 56/342 [00:00<00:00, 2387.85it/s, Materializing param=encoder.stages.1.layers.2.layer_scale_parameter]
# [strict] Loading weights:  17%|█▋        | 57/342 [00:00<00:00, 2420.92it/s, Materializing param=encoder.stages.1.layers.2.layernorm.bias]
# [strict] Loading weights:  17%|█▋        | 57/342 [00:00<00:00, 2416.29it/s, Materializing param=encoder.stages.1.layers.2.layernorm.bias]
# [strict] Loading weights:  17%|█▋        | 58/342 [00:00<00:00, 2449.20it/s, Materializing param=encoder.stages.1.layers.2.layernorm.weight]
# [strict] Loading weights:  17%|█▋        | 58/342 [00:00<00:00, 2444.26it/s, Materializing param=encoder.stages.1.layers.2.layernorm.weight]
# [strict] Loading weights:  17%|█▋        | 59/342 [00:00<00:00, 2477.34it/s, Materializing param=encoder.stages.1.layers.2.pwconv1.bias]
# [strict] Loading weights:  17%|█▋        | 59/342 [00:00<00:00, 2472.64it/s, Materializing param=encoder.stages.1.layers.2.pwconv1.bias]
# [strict] Loading weights:  18%|█▊        | 60/342 [00:00<00:00, 2505.91it/s, Materializing param=encoder.stages.1.layers.2.pwconv1.weight]
# [strict] Loading weights:  18%|█▊        | 60/342 [00:00<00:00, 2501.13it/s, Materializing param=encoder.stages.1.layers.2.pwconv1.weight]
# [strict] Loading weights:  18%|█▊        | 61/342 [00:00<00:00, 2533.80it/s, Materializing param=encoder.stages.1.layers.2.pwconv2.bias]
# [strict] Loading weights:  18%|█▊        | 61/342 [00:00<00:00, 2529.01it/s, Materializing param=encoder.stages.1.layers.2.pwconv2.bias]
# [strict] Loading weights:  18%|█▊        | 62/342 [00:00<00:00, 2561.63it/s, Materializing param=encoder.stages.1.layers.2.pwconv2.weight]
# [strict] Loading weights:  18%|█▊        | 62/342 [00:00<00:00, 2556.90it/s, Materializing param=encoder.stages.1.layers.2.pwconv2.weight]
# [strict] Loading weights:  18%|█▊        | 63/342 [00:00<00:00, 2587.00it/s, Materializing param=encoder.stages.2.downsampling_layer.0.bias]
# [strict] Loading weights:  18%|█▊        | 63/342 [00:00<00:00, 2581.36it/s, Materializing param=encoder.stages.2.downsampling_layer.0.bias]
# [strict] Loading weights:  19%|█▊        | 64/342 [00:00<00:00, 2612.28it/s, Materializing param=encoder.stages.2.downsampling_layer.0.weight]
# [strict] Loading weights:  19%|█▊        | 64/342 [00:00<00:00, 2607.23it/s, Materializing param=encoder.stages.2.downsampling_layer.0.weight]
# [strict] Loading weights:  19%|█▉        | 65/342 [00:00<00:00, 2639.18it/s, Materializing param=encoder.stages.2.downsampling_layer.1.bias]
# [strict] Loading weights:  19%|█▉        | 65/342 [00:00<00:00, 2634.31it/s, Materializing param=encoder.stages.2.downsampling_layer.1.bias]
# [strict] Loading weights:  19%|█▉        | 66/342 [00:00<00:00, 2666.05it/s, Materializing param=encoder.stages.2.downsampling_layer.1.weight]
# [strict] Loading weights:  19%|█▉        | 66/342 [00:00<00:00, 2661.23it/s, Materializing param=encoder.stages.2.downsampling_layer.1.weight]
# [strict] Loading weights:  20%|█▉        | 67/342 [00:00<00:00, 2692.80it/s, Materializing param=encoder.stages.2.layers.0.dwconv.bias]
# [strict] Loading weights:  20%|█▉        | 67/342 [00:00<00:00, 2687.88it/s, Materializing param=encoder.stages.2.layers.0.dwconv.bias]
# [strict] Loading weights:  20%|█▉        | 68/342 [00:00<00:00, 2718.10it/s, Materializing param=encoder.stages.2.layers.0.dwconv.weight]
# [strict] Loading weights:  20%|█▉        | 68/342 [00:00<00:00, 2713.08it/s, Materializing param=encoder.stages.2.layers.0.dwconv.weight]
# [strict] Loading weights:  20%|██        | 69/342 [00:00<00:00, 2742.80it/s, Materializing param=encoder.stages.2.layers.0.layer_scale_parameter]
# [strict] Loading weights:  20%|██        | 69/342 [00:00<00:00, 2737.62it/s, Materializing param=encoder.stages.2.layers.0.layer_scale_parameter]
# [strict] Loading weights:  20%|██        | 70/342 [00:00<00:00, 2768.07it/s, Materializing param=encoder.stages.2.layers.0.layernorm.bias]
# [strict] Loading weights:  20%|██        | 70/342 [00:00<00:00, 2760.42it/s, Materializing param=encoder.stages.2.layers.0.layernorm.bias]
# [strict] Loading weights:  21%|██        | 71/342 [00:00<00:00, 2789.78it/s, Materializing param=encoder.stages.2.layers.0.layernorm.weight]
# [strict] Loading weights:  21%|██        | 71/342 [00:00<00:00, 2783.76it/s, Materializing param=encoder.stages.2.layers.0.layernorm.weight]
# [strict] Loading weights:  21%|██        | 72/342 [00:00<00:00, 2813.53it/s, Materializing param=encoder.stages.2.layers.0.pwconv1.bias]
# [strict] Loading weights:  21%|██        | 72/342 [00:00<00:00, 2808.45it/s, Materializing param=encoder.stages.2.layers.0.pwconv1.bias]
# [strict] Loading weights:  21%|██▏       | 73/342 [00:00<00:00, 2838.06it/s, Materializing param=encoder.stages.2.layers.0.pwconv1.weight]
# [strict] Loading weights:  21%|██▏       | 73/342 [00:00<00:00, 2833.02it/s, Materializing param=encoder.stages.2.layers.0.pwconv1.weight]
# [strict] Loading weights:  22%|██▏       | 74/342 [00:00<00:00, 2862.53it/s, Materializing param=encoder.stages.2.layers.0.pwconv2.bias]
# [strict] Loading weights:  22%|██▏       | 74/342 [00:00<00:00, 2857.42it/s, Materializing param=encoder.stages.2.layers.0.pwconv2.bias]
# [strict] Loading weights:  22%|██▏       | 75/342 [00:00<00:00, 2886.70it/s, Materializing param=encoder.stages.2.layers.0.pwconv2.weight]
# [strict] Loading weights:  22%|██▏       | 75/342 [00:00<00:00, 2881.57it/s, Materializing param=encoder.stages.2.layers.0.pwconv2.weight]
# [strict] Loading weights:  22%|██▏       | 76/342 [00:00<00:00, 2910.82it/s, Materializing param=encoder.stages.2.layers.1.dwconv.bias]
# [strict] Loading weights:  22%|██▏       | 76/342 [00:00<00:00, 2905.81it/s, Materializing param=encoder.stages.2.layers.1.dwconv.bias]
# [strict] Loading weights:  23%|██▎       | 77/342 [00:00<00:00, 2934.55it/s, Materializing param=encoder.stages.2.layers.1.dwconv.weight]
# [strict] Loading weights:  23%|██▎       | 77/342 [00:00<00:00, 2929.38it/s, Materializing param=encoder.stages.2.layers.1.dwconv.weight]
# [strict] Loading weights:  23%|██▎       | 78/342 [00:00<00:00, 2955.15it/s, Materializing param=encoder.stages.2.layers.1.layer_scale_parameter]
# [strict] Loading weights:  23%|██▎       | 78/342 [00:00<00:00, 2949.66it/s, Materializing param=encoder.stages.2.layers.1.layer_scale_parameter]
# [strict] Loading weights:  23%|██▎       | 79/342 [00:00<00:00, 2974.28it/s, Materializing param=encoder.stages.2.layers.1.layernorm.bias]
# [strict] Loading weights:  23%|██▎       | 79/342 [00:00<00:00, 2968.74it/s, Materializing param=encoder.stages.2.layers.1.layernorm.bias]
# [strict] Loading weights:  23%|██▎       | 80/342 [00:00<00:00, 2994.22it/s, Materializing param=encoder.stages.2.layers.1.layernorm.weight]
# [strict] Loading weights:  23%|██▎       | 80/342 [00:00<00:00, 2988.30it/s, Materializing param=encoder.stages.2.layers.1.layernorm.weight]
# [strict] Loading weights:  24%|██▎       | 81/342 [00:00<00:00, 3014.81it/s, Materializing param=encoder.stages.2.layers.1.pwconv1.bias]
# [strict] Loading weights:  24%|██▎       | 81/342 [00:00<00:00, 3008.91it/s, Materializing param=encoder.stages.2.layers.1.pwconv1.bias]
# [strict] Loading weights:  24%|██▍       | 82/342 [00:00<00:00, 3034.90it/s, Materializing param=encoder.stages.2.layers.1.pwconv1.weight]
# [strict] Loading weights:  24%|██▍       | 82/342 [00:00<00:00, 3029.05it/s, Materializing param=encoder.stages.2.layers.1.pwconv1.weight]
# [strict] Loading weights:  24%|██▍       | 83/342 [00:00<00:00, 3054.23it/s, Materializing param=encoder.stages.2.layers.1.pwconv2.bias]
# [strict] Loading weights:  24%|██▍       | 83/342 [00:00<00:00, 3048.27it/s, Materializing param=encoder.stages.2.layers.1.pwconv2.bias]
# [strict] Loading weights:  25%|██▍       | 84/342 [00:00<00:00, 3071.46it/s, Materializing param=encoder.stages.2.layers.1.pwconv2.weight]
# [strict] Loading weights:  25%|██▍       | 84/342 [00:00<00:00, 3064.70it/s, Materializing param=encoder.stages.2.layers.1.pwconv2.weight]
# [strict] Loading weights:  25%|██▍       | 85/342 [00:00<00:00, 3088.62it/s, Materializing param=encoder.stages.2.layers.2.dwconv.bias]
# [strict] Loading weights:  25%|██▍       | 85/342 [00:00<00:00, 3082.58it/s, Materializing param=encoder.stages.2.layers.2.dwconv.bias]
# [strict] Loading weights:  25%|██▌       | 86/342 [00:00<00:00, 3107.75it/s, Materializing param=encoder.stages.2.layers.2.dwconv.weight]
# [strict] Loading weights:  25%|██▌       | 86/342 [00:00<00:00, 3101.92it/s, Materializing param=encoder.stages.2.layers.2.dwconv.weight]
# [strict] Loading weights:  25%|██▌       | 87/342 [00:00<00:00, 3127.07it/s, Materializing param=encoder.stages.2.layers.2.layer_scale_parameter]
# [strict] Loading weights:  25%|██▌       | 87/342 [00:00<00:00, 3121.08it/s, Materializing param=encoder.stages.2.layers.2.layer_scale_parameter]
# [strict] Loading weights:  26%|██▌       | 88/342 [00:00<00:00, 3146.14it/s, Materializing param=encoder.stages.2.layers.2.layernorm.bias]
# [strict] Loading weights:  26%|██▌       | 88/342 [00:00<00:00, 3139.32it/s, Materializing param=encoder.stages.2.layers.2.layernorm.bias]
# [strict] Loading weights:  26%|██▌       | 89/342 [00:00<00:00, 3165.00it/s, Materializing param=encoder.stages.2.layers.2.layernorm.weight]
# [strict] Loading weights:  26%|██▌       | 89/342 [00:00<00:00, 3159.48it/s, Materializing param=encoder.stages.2.layers.2.layernorm.weight]
# [strict] Loading weights:  26%|██▋       | 90/342 [00:00<00:00, 3184.96it/s, Materializing param=encoder.stages.2.layers.2.pwconv1.bias]
# [strict] Loading weights:  26%|██▋       | 90/342 [00:00<00:00, 3179.59it/s, Materializing param=encoder.stages.2.layers.2.pwconv1.bias]
# [strict] Loading weights:  27%|██▋       | 91/342 [00:00<00:00, 3202.08it/s, Materializing param=encoder.stages.2.layers.2.pwconv1.weight]
# [strict] Loading weights:  27%|██▋       | 91/342 [00:00<00:00, 3193.78it/s, Materializing param=encoder.stages.2.layers.2.pwconv1.weight]
# [strict] Loading weights:  27%|██▋       | 92/342 [00:00<00:00, 3218.83it/s, Materializing param=encoder.stages.2.layers.2.pwconv2.bias]
# [strict] Loading weights:  27%|██▋       | 92/342 [00:00<00:00, 3213.70it/s, Materializing param=encoder.stages.2.layers.2.pwconv2.bias]
# [strict] Loading weights:  27%|██▋       | 93/342 [00:00<00:00, 3239.22it/s, Materializing param=encoder.stages.2.layers.2.pwconv2.weight]
# [strict] Loading weights:  27%|██▋       | 93/342 [00:00<00:00, 3234.15it/s, Materializing param=encoder.stages.2.layers.2.pwconv2.weight]
# [strict] Loading weights:  27%|██▋       | 94/342 [00:00<00:00, 3259.73it/s, Materializing param=encoder.stages.2.layers.3.dwconv.bias]
# [strict] Loading weights:  27%|██▋       | 94/342 [00:00<00:00, 3254.65it/s, Materializing param=encoder.stages.2.layers.3.dwconv.bias]
# [strict] Loading weights:  28%|██▊       | 95/342 [00:00<00:00, 3279.96it/s, Materializing param=encoder.stages.2.layers.3.dwconv.weight]
# [strict] Loading weights:  28%|██▊       | 95/342 [00:00<00:00, 3274.89it/s, Materializing param=encoder.stages.2.layers.3.dwconv.weight]
# [strict] Loading weights:  28%|██▊       | 96/342 [00:00<00:00, 3299.71it/s, Materializing param=encoder.stages.2.layers.3.layer_scale_parameter]
# [strict] Loading weights:  28%|██▊       | 96/342 [00:00<00:00, 3294.36it/s, Materializing param=encoder.stages.2.layers.3.layer_scale_parameter]
# [strict] Loading weights:  28%|██▊       | 97/342 [00:00<00:00, 3319.12it/s, Materializing param=encoder.stages.2.layers.3.layernorm.bias]
# [strict] Loading weights:  28%|██▊       | 97/342 [00:00<00:00, 3313.93it/s, Materializing param=encoder.stages.2.layers.3.layernorm.bias]
# [strict] Loading weights:  29%|██▊       | 98/342 [00:00<00:00, 3335.24it/s, Materializing param=encoder.stages.2.layers.3.layernorm.weight]
# [strict] Loading weights:  29%|██▊       | 98/342 [00:00<00:00, 3329.59it/s, Materializing param=encoder.stages.2.layers.3.layernorm.weight]
# [strict] Loading weights:  29%|██▉       | 99/342 [00:00<00:00, 3350.68it/s, Materializing param=encoder.stages.2.layers.3.pwconv1.bias]
# [strict] Loading weights:  29%|██▉       | 99/342 [00:00<00:00, 3345.23it/s, Materializing param=encoder.stages.2.layers.3.pwconv1.bias]
# [strict] Loading weights:  29%|██▉       | 100/342 [00:00<00:00, 3369.43it/s, Materializing param=encoder.stages.2.layers.3.pwconv1.weight]
# [strict] Loading weights:  29%|██▉       | 100/342 [00:00<00:00, 3364.24it/s, Materializing param=encoder.stages.2.layers.3.pwconv1.weight]
# [strict] Loading weights:  30%|██▉       | 101/342 [00:00<00:00, 3387.67it/s, Materializing param=encoder.stages.2.layers.3.pwconv2.bias]
# [strict] Loading weights:  30%|██▉       | 101/342 [00:00<00:00, 3382.53it/s, Materializing param=encoder.stages.2.layers.3.pwconv2.bias]
# [strict] Loading weights:  30%|██▉       | 102/342 [00:00<00:00, 3406.61it/s, Materializing param=encoder.stages.2.layers.3.pwconv2.weight]
# [strict] Loading weights:  30%|██▉       | 102/342 [00:00<00:00, 3401.46it/s, Materializing param=encoder.stages.2.layers.3.pwconv2.weight]
# [strict] Loading weights:  30%|███       | 103/342 [00:00<00:00, 3425.47it/s, Materializing param=encoder.stages.2.layers.4.dwconv.bias]
# [strict] Loading weights:  30%|███       | 103/342 [00:00<00:00, 3420.32it/s, Materializing param=encoder.stages.2.layers.4.dwconv.bias]
# [strict] Loading weights:  30%|███       | 104/342 [00:00<00:00, 3443.98it/s, Materializing param=encoder.stages.2.layers.4.dwconv.weight]
# [strict] Loading weights:  30%|███       | 104/342 [00:00<00:00, 3438.74it/s, Materializing param=encoder.stages.2.layers.4.dwconv.weight]
# [strict] Loading weights:  31%|███       | 105/342 [00:00<00:00, 3460.57it/s, Materializing param=encoder.stages.2.layers.4.layer_scale_parameter]
# [strict] Loading weights:  31%|███       | 105/342 [00:00<00:00, 3454.51it/s, Materializing param=encoder.stages.2.layers.4.layer_scale_parameter]
# [strict] Loading weights:  31%|███       | 106/342 [00:00<00:00, 3476.45it/s, Materializing param=encoder.stages.2.layers.4.layernorm.bias]
# [strict] Loading weights:  31%|███       | 106/342 [00:00<00:00, 3471.08it/s, Materializing param=encoder.stages.2.layers.4.layernorm.bias]
# [strict] Loading weights:  31%|███▏      | 107/342 [00:00<00:00, 3494.00it/s, Materializing param=encoder.stages.2.layers.4.layernorm.weight]
# [strict] Loading weights:  31%|███▏      | 107/342 [00:00<00:00, 3488.76it/s, Materializing param=encoder.stages.2.layers.4.layernorm.weight]
# [strict] Loading weights:  32%|███▏      | 108/342 [00:00<00:00, 3511.89it/s, Materializing param=encoder.stages.2.layers.4.pwconv1.bias]
# [strict] Loading weights:  32%|███▏      | 108/342 [00:00<00:00, 3506.73it/s, Materializing param=encoder.stages.2.layers.4.pwconv1.bias]
# [strict] Loading weights:  32%|███▏      | 109/342 [00:00<00:00, 3529.82it/s, Materializing param=encoder.stages.2.layers.4.pwconv1.weight]
# [strict] Loading weights:  32%|███▏      | 109/342 [00:00<00:00, 3524.65it/s, Materializing param=encoder.stages.2.layers.4.pwconv1.weight]
# [strict] Loading weights:  32%|███▏      | 110/342 [00:00<00:00, 3547.72it/s, Materializing param=encoder.stages.2.layers.4.pwconv2.bias]
# [strict] Loading weights:  32%|███▏      | 110/342 [00:00<00:00, 3542.57it/s, Materializing param=encoder.stages.2.layers.4.pwconv2.bias]
# [strict] Loading weights:  32%|███▏      | 111/342 [00:00<00:00, 3565.44it/s, Materializing param=encoder.stages.2.layers.4.pwconv2.weight]
# [strict] Loading weights:  32%|███▏      | 111/342 [00:00<00:00, 3560.34it/s, Materializing param=encoder.stages.2.layers.4.pwconv2.weight]
# [strict] Loading weights:  33%|███▎      | 112/342 [00:00<00:00, 3583.18it/s, Materializing param=encoder.stages.2.layers.5.dwconv.bias]
# [strict] Loading weights:  33%|███▎      | 112/342 [00:00<00:00, 3576.22it/s, Materializing param=encoder.stages.2.layers.5.dwconv.bias]
# [strict] Loading weights:  33%|███▎      | 113/342 [00:00<00:00, 3597.80it/s, Materializing param=encoder.stages.2.layers.5.dwconv.weight]
# [strict] Loading weights:  33%|███▎      | 113/342 [00:00<00:00, 3591.15it/s, Materializing param=encoder.stages.2.layers.5.dwconv.weight]
# [strict] Loading weights:  33%|███▎      | 114/342 [00:00<00:00, 3611.16it/s, Materializing param=encoder.stages.2.layers.5.layer_scale_parameter]
# [strict] Loading weights:  33%|███▎      | 114/342 [00:00<00:00, 3605.66it/s, Materializing param=encoder.stages.2.layers.5.layer_scale_parameter]
# [strict] Loading weights:  34%|███▎      | 115/342 [00:00<00:00, 3627.47it/s, Materializing param=encoder.stages.2.layers.5.layernorm.bias]
# [strict] Loading weights:  34%|███▎      | 115/342 [00:00<00:00, 3622.16it/s, Materializing param=encoder.stages.2.layers.5.layernorm.bias]
# [strict] Loading weights:  34%|███▍      | 116/342 [00:00<00:00, 3643.97it/s, Materializing param=encoder.stages.2.layers.5.layernorm.weight]
# [strict] Loading weights:  34%|███▍      | 116/342 [00:00<00:00, 3638.68it/s, Materializing param=encoder.stages.2.layers.5.layernorm.weight]
# [strict] Loading weights:  34%|███▍      | 117/342 [00:00<00:00, 3660.31it/s, Materializing param=encoder.stages.2.layers.5.pwconv1.bias]
# [strict] Loading weights:  34%|███▍      | 117/342 [00:00<00:00, 3655.02it/s, Materializing param=encoder.stages.2.layers.5.pwconv1.bias]
# [strict] Loading weights:  35%|███▍      | 118/342 [00:00<00:00, 3676.81it/s, Materializing param=encoder.stages.2.layers.5.pwconv1.weight]
# [strict] Loading weights:  35%|███▍      | 118/342 [00:00<00:00, 3671.57it/s, Materializing param=encoder.stages.2.layers.5.pwconv1.weight]
# [strict] Loading weights:  35%|███▍      | 119/342 [00:00<00:00, 3693.37it/s, Materializing param=encoder.stages.2.layers.5.pwconv2.bias]
# [strict] Loading weights:  35%|███▍      | 119/342 [00:00<00:00, 3688.16it/s, Materializing param=encoder.stages.2.layers.5.pwconv2.bias]
# [strict] Loading weights:  35%|███▌      | 120/342 [00:00<00:00, 3706.55it/s, Materializing param=encoder.stages.2.layers.5.pwconv2.weight]
# [strict] Loading weights:  35%|███▌      | 120/342 [00:00<00:00, 3700.99it/s, Materializing param=encoder.stages.2.layers.5.pwconv2.weight]
# [strict] Loading weights:  35%|███▌      | 121/342 [00:00<00:00, 3720.94it/s, Materializing param=encoder.stages.2.layers.6.dwconv.bias]
# [strict] Loading weights:  35%|███▌      | 121/342 [00:00<00:00, 3715.50it/s, Materializing param=encoder.stages.2.layers.6.dwconv.bias]
# [strict] Loading weights:  36%|███▌      | 122/342 [00:00<00:00, 3736.22it/s, Materializing param=encoder.stages.2.layers.6.dwconv.weight]
# [strict] Loading weights:  36%|███▌      | 122/342 [00:00<00:00, 3730.85it/s, Materializing param=encoder.stages.2.layers.6.dwconv.weight]
# [strict] Loading weights:  36%|███▌      | 123/342 [00:00<00:00, 3751.37it/s, Materializing param=encoder.stages.2.layers.6.layer_scale_parameter]
# [strict] Loading weights:  36%|███▌      | 123/342 [00:00<00:00, 3745.89it/s, Materializing param=encoder.stages.2.layers.6.layer_scale_parameter]
# [strict] Loading weights:  36%|███▋      | 124/342 [00:00<00:00, 3766.42it/s, Materializing param=encoder.stages.2.layers.6.layernorm.bias]
# [strict] Loading weights:  36%|███▋      | 124/342 [00:00<00:00, 3760.81it/s, Materializing param=encoder.stages.2.layers.6.layernorm.bias]
# [strict] Loading weights:  37%|███▋      | 125/342 [00:00<00:00, 3781.00it/s, Materializing param=encoder.stages.2.layers.6.layernorm.weight]
# [strict] Loading weights:  37%|███▋      | 125/342 [00:00<00:00, 3775.69it/s, Materializing param=encoder.stages.2.layers.6.layernorm.weight]
# [strict] Loading weights:  37%|███▋      | 126/342 [00:00<00:00, 3796.05it/s, Materializing param=encoder.stages.2.layers.6.pwconv1.bias]
# [strict] Loading weights:  37%|███▋      | 126/342 [00:00<00:00, 3790.58it/s, Materializing param=encoder.stages.2.layers.6.pwconv1.bias]
# [strict] Loading weights:  37%|███▋      | 127/342 [00:00<00:00, 3808.97it/s, Materializing param=encoder.stages.2.layers.6.pwconv1.weight]
# [strict] Loading weights:  37%|███▋      | 127/342 [00:00<00:00, 3802.96it/s, Materializing param=encoder.stages.2.layers.6.pwconv1.weight]
# [strict] Loading weights:  37%|███▋      | 128/342 [00:00<00:00, 3819.05it/s, Materializing param=encoder.stages.2.layers.6.pwconv2.bias]
# [strict] Loading weights:  37%|███▋      | 128/342 [00:00<00:00, 3812.62it/s, Materializing param=encoder.stages.2.layers.6.pwconv2.bias]
# [strict] Loading weights:  38%|███▊      | 129/342 [00:00<00:00, 3830.31it/s, Materializing param=encoder.stages.2.layers.6.pwconv2.weight]
# [strict] Loading weights:  38%|███▊      | 129/342 [00:00<00:00, 3824.97it/s, Materializing param=encoder.stages.2.layers.6.pwconv2.weight]
# [strict] Loading weights:  38%|███▊      | 130/342 [00:00<00:00, 3844.86it/s, Materializing param=encoder.stages.2.layers.7.dwconv.bias]
# [strict] Loading weights:  38%|███▊      | 130/342 [00:00<00:00, 3839.59it/s, Materializing param=encoder.stages.2.layers.7.dwconv.bias]
# [strict] Loading weights:  38%|███▊      | 131/342 [00:00<00:00, 3859.09it/s, Materializing param=encoder.stages.2.layers.7.dwconv.weight]
# [strict] Loading weights:  38%|███▊      | 131/342 [00:00<00:00, 3853.84it/s, Materializing param=encoder.stages.2.layers.7.dwconv.weight]
# [strict] Loading weights:  39%|███▊      | 132/342 [00:00<00:00, 3873.59it/s, Materializing param=encoder.stages.2.layers.7.layer_scale_parameter]
# [strict] Loading weights:  39%|███▊      | 132/342 [00:00<00:00, 3868.26it/s, Materializing param=encoder.stages.2.layers.7.layer_scale_parameter]
# [strict] Loading weights:  39%|███▉      | 133/342 [00:00<00:00, 3887.81it/s, Materializing param=encoder.stages.2.layers.7.layernorm.bias]
# [strict] Loading weights:  39%|███▉      | 133/342 [00:00<00:00, 3879.70it/s, Materializing param=encoder.stages.2.layers.7.layernorm.bias]
# [strict] Loading weights:  39%|███▉      | 134/342 [00:00<00:00, 3894.35it/s, Materializing param=encoder.stages.2.layers.7.layernorm.weight]
# [strict] Loading weights:  39%|███▉      | 134/342 [00:00<00:00, 3888.10it/s, Materializing param=encoder.stages.2.layers.7.layernorm.weight]
# [strict] Loading weights:  39%|███▉      | 135/342 [00:00<00:00, 3907.01it/s, Materializing param=encoder.stages.2.layers.7.pwconv1.bias]
# [strict] Loading weights:  39%|███▉      | 135/342 [00:00<00:00, 3901.71it/s, Materializing param=encoder.stages.2.layers.7.pwconv1.bias]
# [strict] Loading weights:  40%|███▉      | 136/342 [00:00<00:00, 3920.99it/s, Materializing param=encoder.stages.2.layers.7.pwconv1.weight]
# [strict] Loading weights:  40%|███▉      | 136/342 [00:00<00:00, 3915.87it/s, Materializing param=encoder.stages.2.layers.7.pwconv1.weight]
# [strict] Loading weights:  40%|████      | 137/342 [00:00<00:00, 3935.16it/s, Materializing param=encoder.stages.2.layers.7.pwconv2.bias]
# ...
# [proposed] [16:07:17]   Clinical R@1(all)=15.65%  Clinical R@1(valid)=41.55% (i2t_n=142, t2i_n=142)  MRR=8.50%
# [proposed] [16:07:17]   (best=3.45% @ ep25)
# [strict] [16:10:27] Ep[133/150] Phase2 loss=1.7289 (main=1.7205 clinical=0.0000 clinical_w=0.0000 aux=0.4230) T=11.1 batches=503 opt_steps=101 t=241s
# [proposed] [16:11:36] Ep[126/150] Phase2 loss=1.0597 (main=1.0208 clinical=0.9233 clinical_w=0.0400 aux=0.1024) T=10.1 batches=503 opt_steps=101 t=254s
# [strict] [16:14:33] Ep[134/150] Phase2 loss=1.7266 (main=1.7182 clinical=0.0000 clinical_w=0.0000 aux=0.4232) T=11.1 batches=503 opt_steps=101 t=241s
# [proposed] [16:15:54] Ep[127/150] Phase2 loss=1.0577 (main=1.0187 clinical=0.9282 clinical_w=0.0400 aux=0.0934) T=10.1 batches=503 opt_steps=101 t=253s
# [strict] [16:18:39] Ep[135/150] Phase2 loss=1.7357 (main=1.7273 clinical=0.0000 clinical_w=0.0000 aux=0.4229) T=11.1 batches=503 opt_steps=101 t=241s
# [proposed] [17:56:22]   Mean Strict  R@1=3.05%
# [proposed] [17:56:22]
# [proposed] [17:56:22]   [CLUSTER - shared pathology]
# [proposed] [17:56:22]   i2t | R@1= 63.13%  R@5= 75.86%  R@10= 81.70%
# [proposed] [17:56:22]   t2i | R@1= 64.19%  R@5= 96.55%  R@10= 98.14%
# [proposed] [17:56:22]   Mean Cluster R@1=63.66%
# [proposed] [17:56:22]   Clinical R@1(all)=16.05%  Clinical R@1(valid)=42.61% (i2t_n=142, t2i_n=142)  MRR=8.63%
# [proposed] [17:56:22]   (best=3.45% @ ep25)
# [proposed] [17:56:27] Final test evaluation
# [proposed] [17:56:31] Loaded best checkpoint (ep25, val Strict R@1=3.45%)
# [proposed] [17:57:06]   [STRICT  - same patient]
# [proposed] [17:57:06]   i2t | R@1=  3.98%  R@5= 12.47%  R@10= 22.55%
# [proposed] [17:57:06]   t2i | R@1=  3.45%  R@5= 15.38%  R@10= 24.40%
# [proposed] [17:57:06]   Mean Strict  R@1=3.71%
# [proposed] [17:57:06]
# [proposed] [17:57:06]   [CLUSTER - shared pathology]
# [proposed] [17:57:06]   i2t | R@1= 57.82%  R@5= 83.29%  R@10= 89.12%
# [proposed] [17:57:06]   t2i | R@1= 62.60%  R@5= 92.04%  R@10= 96.55%
# [proposed] [17:57:06]   Mean Cluster R@1=60.21%
# [proposed] [17:57:06]   Clinical R@1(all)=15.52%  Clinical R@1(valid)=39.80% (i2t_n=147, t2i_n=147)  MRR=10.13%
# [proposed] [17:57:06] DONE. Outputs saved to: /kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/proposed
# FINISHED: strict returncode 0 log /kaggle/working/logs/convnext_bioclinicalbert_true_run_seed42_split42_strict.log
# FINISHED: proposed returncode 0 log /kaggle/working/logs/convnext_bioclinicalbert_true_run_seed42_split42_proposed.log
# elapsed_seconds: 39238.8
#
# === Output check ===
#
#  strict /kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/strict
# ['run_summary.txt', 'train.log', 'launcher_config.json', 'history.csv', 'test_results.json', 'progress.log', 'config.json', 'latest_metrics.json', 'best.pt', 'training_history_lvtm_compat.csv', 'last.pt', 'best_summary.json']
# train.log True 0.027
# progress.log True 0.011
# history.csv True 0.015
# latest_metrics.json True 0.001
# test_results.json True 0.001
# last.pt True 2272.49
# best.pt True 759.003
# launcher_config.json True 0.001
# launcher_log True 0.19
#
#  proposed /kaggle/working/runs/convnext_bioclinicalbert_true_run_seed42_split42/proposed
# ['run_summary.txt', 'train.log', 'launcher_config.json', 'history.csv', 'test_results.json', 'progress.log', 'config.json', 'latest_metrics.json', 'best.pt', 'training_history_lvtm_compat.csv', 'last.pt', 'best_summary.json']
# train.log True 0.027
# progress.log True 0.011
# history.csv True 0.015
# latest_metrics.json True 0.001
# test_results.json True 0.001
# last.pt True 2272.49
# best.pt True 759.003
# launcher_config.json True 0.001
# launcher_log True 0.19
#
# === Zip outputs ===
# Created: /kaggle/working/convnext_bioclinicalbert_true_run_seed42_split42_outputs.zip
# size_mb: 5325.02
# DONE
